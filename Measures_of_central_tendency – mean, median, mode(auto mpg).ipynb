# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('auto-mpg.csv')

# %%
data
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
# To find mean of the data
print(data.mean(numeric_only=True))
# Out:
# mpg         23.445918
# cyl          5.471939
# displ      194.411990
# hp         104.469388
# weight    2977.584184
# accel       15.541327
# yr          75.979592
# origin       1.576531
# dtype: float64

# %%
#To find median of the data
print(data.median(numeric_only=True))
# Out:
# mpg         22.75
# cyl          4.00
# displ      151.00
# hp          93.50
# weight    2803.50
# accel       15.50
# yr          76.00
# origin       1.00
# dtype: float64

# %%
#To find mode of the data
print(data.mode(numeric_only=True))
# Out:
#     mpg  cyl  displ     hp  weight  accel    yr  origin
# 0  13.0  4.0   97.0  150.0    1985   14.5  73.0     1.0
# 1   NaN  NaN    NaN    NaN    2130    NaN   NaN     NaN

# %%
#To find the range of the data
print(data.max(numeric_only=True) - data.min(numeric_only=True))
# Out:
# mpg         37.6
# cyl          5.0
# displ      387.0
# hp         184.0
# weight    3527.0
# accel       16.8
# yr          12.0
# origin       2.0
# dtype: float64

# %%
  # To find the variance of the data
  print(data.var(numeric_only=True))
# Out:
# mpg           60.918142
# cyl            2.909696
# displ      10950.367554
# hp          1481.569393
# weight    721484.709008
# accel          7.611331
# yr            13.569915
# origin         0.648860
# dtype: float64

# %%
# To find the standard deviation of the data
print(data.std(numeric_only=True))
# Out:
# mpg         7.805007
# cyl         1.705783
# displ     104.644004
# hp         38.491160
# weight    849.402560
# accel       2.758864
# yr          3.683737
# origin      0.805518
# dtype: float64

# %%
# To obtain only the numeric columns
numeric_columns = data.select_dtypes(include="number")
print("Numeric columns:", numeric_columns)
# Out:
# Numeric columns:       mpg  cyl  displ   hp  weight  accel  yr  origin
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
# [392 rows x 8 columns]

# %%
#To print the quartiles
print(data.quantile([0.25,0.5,0.75],numeric_only=True))
# Out:
#         mpg  cyl   displ     hp   weight   accel    yr  origin
# 0.25  17.00  4.0  105.00   75.0  2225.25  13.775  73.0     1.0
# 0.50  22.75  4.0  151.00   93.5  2803.50  15.500  76.0     1.0
# 0.75  29.00  8.0  275.75  126.0  3614.75  17.025  79.0     2.0

# %%
#to find the IQR for the data
print(data.quantile(0.75,numeric_only=True) - data.quantile(0.25,numeric_only=True))
# Out:
# mpg         12.00
# cyl          4.00
# displ      170.75
# hp          51.00
# weight    1389.50
# accel        3.25
# yr           6.00
# origin       1.00
# dtype: float64

# %%
# TO convert data into dataframec
numeric_data=pd.DataFrame(numeric_columns)
numeric_data
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
# [392 rows x 8 columns]

# %%
# Mean
for i in numeric_data:
  d=data[i]
  mean=sum(d) / len(d)
  print(f"{i} : {mean}")
# Out:
# mpg : 23.44591836734694
# cyl : 5.471938775510204
# displ : 194.41198979591837
# hp : 104.46938775510205
# weight : 2977.5841836734694
# accel : 15.541326530612228
# yr : 75.9795918367347
# origin : 1.5765306122448979

# %%
# Median
for i in numeric_data:
  d=data[i].tolist()
  d.sort()
  n=len(d)
  if n%2==0:
    median=(d[n//2 - 1] + d[n//2]) / 2
  else:
    median=d[n//2]
  print(f"{i} : {median}")
# Out:
# mpg : 22.75
# cyl : 4.0
# displ : 151.0
# hp : 93.5
# weight : 2803.5
# accel : 15.5
# yr : 76.0
# origin : 1.0

# %%
#Mode
from collections import Counter
for i in numeric_data:
  d=data[i]
  freq=Counter(d)
  max_val=max(freq.values())
  mode=[k for k,v in freq.items() if v==max_val]
  print(f"{i} : {mode}")
# Out:
# mpg : [13.0]
# cyl : [4]
# displ : [97.0]
# hp : [150]
# weight : [2130, 1985]
# accel : [14.5]
# yr : [73]
# origin : [1]

# %%
#Variance
for i in numeric_data:
  d=data[i]
  mean=sum(d)/len(d)
  var=sum((x-mean)**2 for x in d) / len(d)
  print(f"{i} : {var}")
# Out:
# mpg : 60.7627384423157
# cyl : 2.9022737921699275
# displ : 10922.432942979487
# hp : 1477.7898792169979
# weight : 719644.1867906604
# accel : 7.591914566847145
# yr : 13.535297792586439
# origin : 0.647204289879216

# %%
#Standard Deviation
for i in numeric_data:
  d=data[i]
  mean=sum(d)/len(d)
  var=sum((x-mean)**2 for x in d) / len(d)
  std=var**0.5
  print(f"{i} : {std}")
# Out:
# mpg : 7.795045762682584
# cyl : 1.703606114150195
# displ : 104.51044418133284
# hp : 38.442032714425984
# weight : 848.3184465698364
# accel : 2.7553429127509963
# yr : 3.679034899615175
# origin : 0.8044900806593056
